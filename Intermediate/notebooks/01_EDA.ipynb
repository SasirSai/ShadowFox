# %% [markdown]
# # AI-Powered Explainable Loan Approval & Credit Risk Assessment System
#
# ## Phase 1 & 2: Exploratory Data Analysis & Cleaning
#
# This notebook covers the data exploration and preprocessing stages of the project.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('../data/loan_prediction.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import plotly.express as px
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# ModuleNotFoundError: No module named 'plotly'

# %%
# Dataset Overview
print("Shape:", df.shape)
print("\nInfo:")
df.info()

# %%
# Missing Values
missing_values = df.isnull().sum()
missing_values[missing_values > 0]

# %% [markdown]
# Please refer to the `src/preprocessing.py` and Streamlit dashboard for the production-grade implementation of data cleaning and visual analysis.
